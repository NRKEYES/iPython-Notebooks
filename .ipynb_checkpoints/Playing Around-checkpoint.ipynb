# %%
# %matplotlib nbagg

# %%
import seaborn as sns
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", size=4,
           scatter_kws={"s": 50, "alpha": 1})
# Out:
# <img src="data:image/png;base64,...">

# %%
import numpy as np
from scipy.stats import kendalltau
import seaborn as sns
sns.set(style="ticks")

rawData = pandas.read_excel('/Users/Ignare/Copy/School/411L)
rawData.head()

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)

sns.jointplot(x, y, kind="hex", stat_func=kendalltau, color="#4CB391")
# Out:
# <img src="data:image/png;base64,...">

# %%
# !echo $SHELL
# Out:
# /bin/zsh

# %%
# !ssh gibbs
#everything = !ls
# Out:
# Last login: Thu Jul 23 16:38:10 2015 from 129.24.65.152
# ┌─[nkeyes@gibbs] - [~] - [2015-07-23 04:39:44]
# └─[0] =

# %%
import matplotlib.pyplot as plt
import pandas
import numpy
# %matplotlib inline

# For image display
from IPython.display import HTML 
from IPython.display import display

# %%
#Change Working Directory
# %cd ~
# %cd Copy/Work/Research/Hemibonds/
# Out:
# /Users/Ignare
# /Users/Ignare/Copy/Work/Research/Hemibonds

# %%
# !rsync nkeyes@gibbs:~/Cl-HCl/CCSD/repeat/inp.out Cl-full-ccsd-first.out
ma_data = !grep "FINAL SINGLE POINT ENERGY" Cl-full-ccsd-first.out |cut -f2- -d'-'
print ma_data
energy = list(ma_data)


hurray = !grep HURRAY Cl-full-ccsd-first.out
if hurray:
    #Image(filename='test.jpg')
    pic = HTML('<img src="http://www.jillybeans.org/wp-content/uploads/2014/03/The-Dark-Crystal-Picture-1.jpg" width=300/>') 
    display(pic)
    print 'The great convergnce is upon us!'
# Out:
# ['920.062391565879', '920.062391625783']
# <img src="http://www.jillybeans.org/wp-content/uploads/2014/03/The-Dark-Crystal-Picture-1.jpg" width=300/>
# The great convergnce is upon us!

# %%
data = DataFrame(energy)
display(data)
plot = plt.figure(figsize=(10,10))
dots = plot.add_subplot(1,1,1)
dots.scatter(data.index,data[0])
# Out:
#                   0
# 0  920.062391565879
# 1  920.062391625783

# %%
ma_data = !grep -A 5 "INTERNAL COORDINATES (ANGSTROEM)" Cl-full-ccsd-first.out 
ma_data
# Out:
# ['INTERNAL COORDINATES (ANGSTROEM)',
#  '--------------------------------',
#  ' Cl     0   0   0   0.000000     0.000     0.000',
#  ' H      1   0   0   1.286500     0.000     0.000',
#  ' Cl     1   2   0   2.849898    86.271     0.000',
#  '',
#  '--',
#  'INTERNAL COORDINATES (ANGSTROEM)',
#  '--------------------------------',
#  ' Cl     0   0   0   0.000000     0.000     0.000',
#  ' H      1   0   0   1.279843     0.000     0.000',
#  ' Cl     1   2   0   2.929768    86.430     0.000',
#  '',
#  '--',
#  'INTERNAL COORDINATES (ANGSTROEM)',
#  '--------------------------------',
#  ' Cl     0   0   0   0.000000     0.000     0.000',
#  ' H      1   0   0   1.276210     0.000     0.000',
#  ' Cl     1   2   0   3.014406    86.521     0.000',
#  '',
#  '--',
#  'INTERNAL COORDINATES (ANGSTROEM)',
#  '--------------------------------',
#  ' Cl     0   0   0   0.000000     0.000     0.000',
#  ' H      1   0   0   1.276463     0.000     0.000',
# ...

# %%
# %cd ~
# %cd SuperComputers/Cl-HCl/
# !ls
# Out:
# /Users/Ignare
# /Users/Ignare/SuperComputers/Cl-HCl
# CCSD             inp.hess         inp.out          inp.proc1.uno    inp.proc3.qro    inp.proc4.unso   inp.proc6.uno    inp.proc8.qro    inp.trj          molden           test.e3960       test.o3958       well
# blankredo        inp.inp          inp.proc0.qro    inp.proc1.unso   inp.proc3.uno    inp.proc5.qro    inp.proc6.unso   inp.proc8.uno    inp.uno          mpwREDO          test.e3961       test.o3960
# inp.engrad       inp.molden.input inp.proc0.uno    inp.proc2.qro    inp.proc3.unso   inp.proc5.uno    inp.proc7.qro    inp.proc8.unso   inp.unso         orca.pbs         test.e3962       test.o3961
# inp.gbw          inp.nodes        inp.proc0.unso   inp.proc2.uno    inp.proc4.qro    inp.proc5.unso   inp.proc7.uno    inp.prop         inp.xyz          test.e3957       test.e3963       test.o3962
# ...

# %%
import chemlab.io
from chemview import enable_notebook, MolecularViewer
#enable_notebook()


df = chemlab.io.datafile("inp.xyz", 'r')
molecule = df.read('molecule')
molecule.guess_bonds()
mv = MolecularViewer(molecule.r_array, { 'atom_types': molecule.type_array,
                                         'bonds': molecule.bonds })
display(mv.wireframe())
mv
# Out:
# None

# %%
# !rsync nkeyes@gibbs:~/Cl-HCl/CCSD/iso-hx/inp.out hcl-ccsd-first.out
ma_data = !grep "FINAL SINGLE POINT ENERGY" hcl-ccsd-first.out |cut -f2- -d'-'
print ma_data
energy = list(ma_data)


hurray = !grep HURRAY hcl-ccsd-first.out
if hurray:
    #Image(filename='test.jpg')
    pic = HTML('<img src="http://www.jillybeans.org/wp-content/uploads/2014/03/The-Dark-Crystal-Picture-1.jpg" width=300/>') 
    display(pic)
    print 'The great convergnce is upon us!'
# Out:
# ['460.364702076657', '460.364768710573', '460.364770865356', '460.364770867475']
# <img src="http://www.jillybeans.org/wp-content/uploads/2014/03/The-Dark-Crystal-Picture-1.jpg" width=300/>
# The great convergnce is upon us!
